# %% [markdown]
# # Setup Test Environment

# %%
import pandas as pd
import time, os, inspect, sys
import matplotlib.pyplot as plt

# %% [markdown]
# Add upper directory to script_dir so we can import packages from the library

# %%
script_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
sys.path.append(os.path.join(script_dir, os.pardir, os.pardir))

# %% [markdown]
# Setup matplotlib so we can print plots right in this worksheet

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = 16,8

# %% [markdown]
# ### Set the start and end times for the experiment

# %%
start = pd.Timestamp(time.time() - 3600*24, unit='s') #24 hours ago
start = start.replace(hour=21,minute=0, second=0) #start around 20h
end = start.replace(minute=1)

# %% [markdown]
# Import method that fetches Flukso data

# %%
from nialm.library.get_data import get_flukso_data

# %% [markdown]
# Download Flukso data for all sensors of 1 type (default = electricity)

# %%
df = get_flukso_data(start,end)
# Out:
# 43 electricity sensors
# /Library/Python/2.7/site-packages/requests/packages/urllib3/connection.py:251: SecurityWarning: Certificate has no `subjectAltName`, falling back to check for a `commonName` for now. This feature is being removed by major browsers and deprecated by RFC 2818. (See https://github.com/shazow/urllib3/issues/497 for details.)
#   SecurityWarning
# /Library/Python/2.7/site-packages/requests/packages/urllib3/connection.py:251: SecurityWarning: Certificate has no `subjectAltName`, falling back to check for a `commonName` for now. This feature is being removed by major browsers and deprecated by RFC 2818. (See https://github.com/shazow/urllib3/issues/497 for details.)
#   SecurityWarning
# ...

# %% [markdown]
# ### Print all sensor names and plot the derivatives

# %% [markdown]
# This is done so you can select a sensor that has the character you wish to analyse

# %%
for sensor in df:
    print sensor
    
    data = df[sensor].diff() #take the derivative
    
    plt.figure()
    plt.plot_date(data.index,data,'-')
    plt.ylabel("deltaP [W]")
    plt.title(sensor)
# Out:
# b325dbc1a0d62c99a50609e919b9ea06
# ce8ab098fc7479dcb3699f307c8e88a7
# 9afa3357cee100c6a8a5059c63e29295
# d209e2bbb35b82b83cc0de5e8b84a4ff
# 18345d8b39d2b98cde9f652b533f4280
# ad322ec64956ed232cb94a72517004ab
# 56f28789f52236df4647d06111ff515a
# 3aa40023a1683bfec0f01cce8d45fc70
# c1a78eacaa6a82d3257a278d3e99088a
# 1a1dac9c2ac155f95c58bf1d4f4b7d01
# e1dec16012edc11de998aeaa317274d7
# 214ef2d3533899dbf633caeb32e80483
# 06686f304bd7c72a86c3810d2965f4a2
# b841eb895810525017ddc5d932d37eb7
# 8520ae493bcc57574e09b6ff7b13be76
# 53b1eb0479c83dee927fff10b0cb0fe6

# %% [markdown]
# ## Pick one sensor and filter the flanks

# %%
orig_data = df['9afa3357cee100c6a8a5059c63e29295']
orig = orig_data.diff()
data = orig[orig < 0].combine_first(orig[orig > 0])
plt.figure()
plt.plot_date(orig.index,orig,'-')
plt.plot_date(data.index,data,'o',label="flanks")
plt.legend()

# %% [markdown]
# # IMPORT METHODS and begin test

# %%
from nialm.library.block_detection_methods import *

# %%
tol = 0.1

# %%
negatives = data[data < 0]
positives = data[data > 0]
    
plt.plot_date(orig.index,orig,'-')
plt.plot_date(negatives.index,negatives,'o')
plt.plot_date(positives.index,positives,'o')

# %%
def find_multiple(series):
    for i in range(0,series.size):
        print series[i]
        if i==series.size-1: continue
        if timediff(series,i) == 1:
            print "match"
            
            
            event = Event(index=series.index[i],value=series[i])
            event.add_point(index=series.index[i+1],value=series[i+1])
            while True:
                i += 1
                if i==series.size-1 or timediff(series,i) !=1:
                    break
                else:
                    event.add_point(index=series.index[i+1],value=series[i+1])
            return event
            """
    return None
    

def timediff(series,i):
    return int((series.index[i+1] - series.index[i])/np.timedelta64(1,'s'))

# %%
def match_single_positive(series,event):
    target_value = event.get_total_value()
    for ix,val in series[0:event.get_first_index()][::-1].iteritems():
        if is_match(vala=val,valb=target_value,tol=tol):
            on = Event(index=ix,value=val)
            block = Block(on,event)
            return block

# %%
def match_single_negative(series,event):
    target_value = event.get_total_value()
    for ix,val in series[event.get_last_index():].iteritems():
        if is_match(vala=target_value,valb=val,tol=tol):
            off = Event(index=ix,value=val)
            block = Block(event,off)
            return block

# %%
off = find_multiple(negatives[::-1])
print off
if off:
    block = match_single_positive(positives,off)
    print block
# Out:
# -599.999999441
# -1.67638063431e-06
# -29.9999990501
# -29.9999990501
# -59.9999997765
# -1.67638063431e-06
# -29.9999990501
# -29.9999990501
# -59.9999997765
# -1.67638063431e-06
# -59.9999997765
# -59.9999997765
# None

# %%
on = find_multiple(positives,1)
print on
if on:
    block = match_single_negative(negatives,on)
    print block
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-d55e89a77e9d> in <module>()
# ----> 1 on = find_multiple(positives,1)
#       2 print on
#       3 if on:
#       4     block = match_single_negative(negatives,on)
#       5     print block
#
# TypeError: find_multiple() takes exactly 1 argument (2 given)

# %%
block.df.values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-f089bdee492c> in <module>()
# ----> 1 block.df.values
#
# AttributeError: 'NoneType' object has no attribute 'df'

# %%
print negatives
# Out:
# 2015-02-11 21:00:08+00:00    -60.000000
# 2015-02-11 21:00:09+00:00    -60.000000
# 2015-02-11 21:00:10+00:00     -0.000002
# 2015-02-11 21:00:24+00:00    -60.000000
# 2015-02-11 21:00:25+00:00    -29.999999
# 2015-02-11 21:00:26+00:00    -29.999999
# 2015-02-11 21:00:27+00:00     -0.000002
# 2015-02-11 21:00:41+00:00    -60.000000
# 2015-02-11 21:00:42+00:00    -29.999999
# 2015-02-11 21:00:43+00:00    -29.999999
# 2015-02-11 21:00:44+00:00     -0.000002
# 2015-02-11 21:01:00+00:00   -599.999999
# Name: 9afa3357cee100c6a8a5059c63e29295, dtype: float64

# %%
print int((negatives.index[1] - negatives.index[2])/np.timedelta64(1,'s'))
# Out:
# -1
