# %%
import pandas as pd
import time, os, sys, inspect
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
plt.rcParams['figure.figsize'] = 16,8

# %%
script_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
sys.path.append(os.path.join(script_dir, os.pardir, os.pardir))

# %%
start = pd.Timestamp(time.time() - 3600*24, unit='s') #24 hours ago
start = start.replace(hour=18,minute=0, second=0) #start around 20h
end = start.replace(hour=18,minute=10,second=0)

# %%
from nialm.library.get_data import get_flukso_data

# %%
df = get_flukso_data(start,end,sensor='214ef2d3533899dbf633caeb32e80483',token='7d964f8a361a1273594161c67a8ac31e')
# Out:
# /Library/Python/2.7/site-packages/requests/packages/urllib3/connection.py:251: SecurityWarning: Certificate has no `subjectAltName`, falling back to check for a `commonName` for now. This feature is being removed by major browsers and deprecated by RFC 2818. (See https://github.com/shazow/urllib3/issues/497 for details.)
#   SecurityWarning

# %%
from nialm.library.problems import *
#pick a sensor
#sensor = '214ef2d3533899dbf633caeb32e80483'
#problem = Disaggregation_problem(orig_data=df[sensor],mutation_rate=0.1)
problem = Disaggregation_problem(orig_data=df,mutation_rate=0)

plt.figure()
plt.plot_date(problem.df_orig.index,problem.df_orig,'-',label="Instantaneous Power")
plt.plot_date(problem.df_norm.index,problem.df_norm,'-',label="Normalized Instantaneous Power")
plt.plot_date(problem.df_diff_full.index,problem.df_diff_full,'-',label="1st Derivative")
plt.plot_date(problem.df_diff.index,problem.df_diff,'o',label="Flanks")
plt.figtext(0.5,0.95,["Detection Ceiling = ",problem.score_ceiling," Wh"], fontsize=14, ha='center')
plt.legend()

# %%
pop_size = 5
num_parents = 2
tol = 0.1

# %% [markdown]
# # Test a Population

# %%
from nialm.library.genetic.population import Population
pop = Population(size=pop_size,problem=problem)
print pop
pop.print_individuals()
# Out:
# Size:  5
#
# 	Individual number  0
# 	Number of genes:  1
# Solution percentage:  20.9912536564 %
#
# 	Individual number  1
# 	Number of genes:  1
# Solution percentage:  20.9912536564 %
#
# 	Individual number  2
# 	Number of genes:  1
# Solution percentage:  20.9912536564 %
#
# 	Individual number  3
# 	Number of genes:  1
# Solution percentage:  20.9912536564 %
#
# 	Individual number  4
# 	Number of genes:  1
# Solution percentage:  20.9912536564 %

# %% [markdown]
# ## Test an Individual

# %%
from nialm.library.genetic.individual import Individual
ind = Individual(problem=problem)
print ind
# Out:
# Number of genes:  1
# Solution percentage:  20.9912536564 %

# %%
plt.figure()
plt.plot_date(ind.norm_data.index,ind.norm_data,'-')
plt.plot_date(ind.der_data.index,ind.der_data,'o')
print ind.der_data
# Out:
# 2015-02-12 18:00:18+00:00    50.000000
# 2015-02-12 18:00:26+00:00   -50.000000
# 2015-02-12 18:00:35+00:00    50.000000
# 2015-02-12 18:01:07+00:00   -50.000000
# 2015-02-12 18:01:16+00:00    50.000000
# 2015-02-12 18:01:24+00:00   -50.000000
# 2015-02-12 18:01:33+00:00    50.000000
# 2015-02-12 18:01:41+00:00   -50.000000
# 2015-02-12 18:01:50+00:00    50.000000
# 2015-02-12 18:01:58+00:00   -50.000000
# 2015-02-12 18:02:07+00:00    50.000000
# 2015-02-12 18:02:15+00:00   -50.000000
# 2015-02-12 18:02:24+00:00    50.000000
# 2015-02-12 18:02:48+00:00   -50.000000
# 2015-02-12 18:02:57+00:00    50.000000
# 2015-02-12 18:03:13+00:00   -50.000000
# 2015-02-12 18:05:53+00:00    32.727273
# 2015-02-12 18:07:03+00:00   -32.727273
# 2015-02-12 18:07:14+00:00    32.727273
# 2015-02-12 18:08:14+00:00   -32.727273
# dtype: float64

# %% [markdown]
# ### Test a gene

# %%
from nialm.library.genetic.gene import Gene
gene = Gene(methodlist=problem.methodlist)
print gene
# Out:
# Method:  <nialm.library.block_detection_methods2.Single object at 0x110af2fd0>
# Parameters:  {'polarity': 'pos', 'direction': -1, 'matching_method': 'single'}

# %%
block = gene.exec_method(der_data=ind.der_data,norm_data=ind.norm_data,tol=tol)
print block
# Out:
# On:  2015-02-12 18:07:14+00:00
# Off:  2015-02-12 18:08:14+00:00
# Duration:  61.0
# Power:  31.6715542633
# Score:  0.545454545645

# %% [markdown]
# #### Test Method

# %%
from nialm.library.block_detection_methods2 import *
method = Single()
print method
# Out:
# <nialm.library.block_detection_methods2.Single object at 0x113f04ad0>

# %%
params = {'direction':1,'polarity':'neg','matching_method':'single'}
block = method.execute(params=params, norm_data=ind.norm_data,der_data=ind.der_data,tol=tol)
print block
print block.is_valid(norm_signal=ind.norm_data)
# Out:
# On:  2015-02-12 18:00:18+00:00
# Off:  2015-02-12 18:00:26+00:00
# Duration:  9.0
# Power:  39.9999999627
# Score:  0.111111111008
#
# False

# %%
drawable = block.get_drawable()
plt.plot_date(ind.norm_data.index,ind.norm_data,'-')
plt.plot_date(drawable.index,drawable,'-')

# %% [markdown]
# # Evolve the Population

# %%
pop.sort()
top = pop.individuals[:1]
print top
# Out:
# Number of genes:  1
# Solution percentage:  20.9912536564 %
# []

# %%
for i in range(1,len(pop.individuals)):
    pop.individuals[i] = Individual(problem=problem,genes=pop.individuals[0].genes)
pop.individuals
# Out:
# Number of genes:  11
# Solution percentage:  71.1370262594 %
# Number of genes:  11
# Solution percentage:  77.551020424 %
# Number of genes:  11
# Solution percentage:  87.1720116709 %
# Number of genes:  11
# Solution percentage:  100.0 %
# Number of genes:  11
# Solution percentage:  100.0 %
# [, , , , ]

# %%
pop.sort()
